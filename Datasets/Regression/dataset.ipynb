# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
from prepare_data_framework import Data_Preparer as dp

# %%
data = pd.read_csv('train.csv')

# %%
tdata = data.copy()
tdata['MSSubClass'] = tdata['MSSubClass'].astype('str')

# %%
data.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 1106  1107          20       RL        114.0    10357   Pave   NaN      IR1  \
# 1297  1298         180       RM         35.0     3675   Pave   NaN      Reg
# 238    239          20       RL         93.0    12030   Pave   NaN      Reg
# 675    676         160       RL         24.0     2289   Pave   NaN      Reg
# 1115  1116          20       RL         93.0    12085   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal
# 1106         Lvl    AllPub  ...        0    NaN   NaN         NaN       0  \
# 1297         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 238          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 675          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1115         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1106      5   2007        WD         Normal     179900
# 1297      6   2006       New        Partial     140000
# 238      12   2007       New        Partial     318000
# 675       4   2009        WD         Normal     148500
# 1115     11   2007       New        Partial     318000
#
# [5 rows x 81 columns]

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
preparer = dp(data, cat_threshold=25)

# %%
nan_cols = preparer.print_nans()
nan_cols
# Out:
# LotFrontage: Количество NANов: 259, Относительное кол-во NANов: 0.177, Тип признака: float64
# Alley: Количество NANов: 1369, Относительное кол-во NANов: 0.938, Тип признака: object
# MasVnrType: Количество NANов: 872, Относительное кол-во NANов: 0.597, Тип признака: object
# MasVnrArea: Количество NANов: 8, Относительное кол-во NANов: 0.005, Тип признака: float64
# BsmtQual: Количество NANов: 37, Относительное кол-во NANов: 0.025, Тип признака: object
# BsmtCond: Количество NANов: 37, Относительное кол-во NANов: 0.025, Тип признака: object
# BsmtExposure: Количество NANов: 38, Относительное кол-во NANов: 0.026, Тип признака: object
# BsmtFinType1: Количество NANов: 37, Относительное кол-во NANов: 0.025, Тип признака: object
# BsmtFinType2: Количество NANов: 38, Относительное кол-во NANов: 0.026, Тип признака: object
# Electrical: Количество NANов: 1, Относительное кол-во NANов: 0.001, Тип признака: object
# FireplaceQu: Количество NANов: 690, Относительное кол-во NANов: 0.473, Тип признака: object
# GarageType: Количество NANов: 81, Относительное кол-во NANов: 0.055, Тип признака: object
# GarageYrBlt: Количество NANов: 81, Относительное кол-во NANов: 0.055, Тип признака: float64
# GarageFinish: Количество NANов: 81, Относительное кол-во NANов: 0.055, Тип признака: object
# GarageQual: Количество NANов: 81, Относительное кол-во NANов: 0.055, Тип признака: object
# GarageCond: Количество NANов: 81, Относительное кол-во NANов: 0.055, Тип признака: object
# PoolQC: Количество NANов: 1453, Относительное кол-во NANов: 0.995, Тип признака: object
# Fence: Количество NANов: 1179, Относительное кол-во NANов: 0.808, Тип признака: object
# MiscFeature: Количество NANов: 1406, Относительное кол-во NANов: 0.963, Тип признака: object
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
num_cols, cat_cols, other_cols = preparer.get_columns_type(cat_threshold=25)
# Out:
# Id: int64
#
# Id
# 1       1
# 982     1
# 980     1
# 979     1
# 978     1
#        ..
# 485     1
# 484     1
# 483     1
# 482     1
# 1460    1
# Name: count, Length: 1460, dtype: int64
#
# 1460
#
# MSSubClass: int64
#
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64
#
# 15
#
# MSZoning: object
#
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
# 5
#
# LotFrontage: float64
#
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: count, Length: 110, dtype: int64
#
# 110
#
# LotArea: int64
#
# LotArea
# 7200     25
# 9600     24
# 6000     17
# 9000     14
# 8400     14
#          ..
# 14601     1
# 13682     1
# 4058      1
# 17104     1
# 9717      1
# Name: count, Length: 1073, dtype: int64
#
# 1073
#
# Street: object
#
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
#
# 2
#
# Alley: object
#
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
#
# 2
#
# LotShape: object
#
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
#
# 4
#
# LandContour: object
#
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
#
# 4
#
# Utilities: object
#
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
#
# 2
#
# LotConfig: object
#
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
#
# 5
#
# LandSlope: object
#
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
#
# 3
#
# Neighborhood: object
#
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: count, dtype: int64
#
# 25
#
# Condition1: object
#
# Condition1
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: count, dtype: int64
#
# 9
#
# Condition2: object
#
# Condition2
# Norm      1445
# Feedr        6
# Artery       2
# RRNn         2
# PosN         2
# PosA         1
# RRAn         1
# RRAe         1
# Name: count, dtype: int64
#
# 8
#
# BldgType: object
#
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64
#
# 5
#
# HouseStyle: object
#
# HouseStyle
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: count, dtype: int64
#
# 8
#
# OverallQual: int64
#
# OverallQual
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: count, dtype: int64
#
# 10
#
# OverallCond: int64
#
# OverallCond
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: count, dtype: int64
#
# 9
#
# YearBuilt: int64
#
# YearBuilt
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1875     1
# 1911     1
# 1917     1
# 1872     1
# 1905     1
# Name: count, Length: 112, dtype: int64
#
# 112
#
# YearRemodAdd: int64
#
# YearRemodAdd
# 1950    178
# 2006     97
# 2007     76
# 2005     73
# 2004     62
#        ...
# 2010      6
# 1986      5
# 1952      5
# 1983      5
# 1951      4
# Name: count, Length: 61, dtype: int64
#
# 61
#
# RoofStyle: object
#
# RoofStyle
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: count, dtype: int64
#
# 6
#
# RoofMatl: object
#
# RoofMatl
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Metal         1
# Membran       1
# Roll          1
# ClyTile       1
# Name: count, dtype: int64
#
# 8
#
# Exterior1st: object
#
# Exterior1st
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# AsphShn      1
# ImStucc      1
# CBlock       1
# Name: count, dtype: int64
#
# 15
#
# Exterior2nd: object
#
# Exterior2nd
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: count, dtype: int64
#
# 16
#
# MasVnrType: object
#
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64
#
# 3
#
# MasVnrArea: float64
#
# MasVnrArea
# 0.0      861
# 180.0      8
# 72.0       8
# 108.0      8
# 120.0      7
#         ...
# 562.0      1
# 89.0       1
# 921.0      1
# 762.0      1
# 119.0      1
# Name: count, Length: 327, dtype: int64
#
# 327
#
# ExterQual: object
#
# ExterQual
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: count, dtype: int64
#
# 4
#
# ExterCond: object
#
# ExterCond
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: count, dtype: int64
#
# 5
#
# Foundation: object
#
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64
#
# 6
#
# BsmtQual: object
#
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64
#
# 4
#
# BsmtCond: object
#
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64
#
# 4
#
# BsmtExposure: object
#
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64
#
# 4
#
# BsmtFinType1: object
#
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64
#
# 6
#
# BsmtFinSF1: int64
#
# BsmtFinSF1
# 0       467
# 24       12
# 16        9
# 686       5
# 662       5
#        ...
# 1338      1
# 1324      1
# 1460      1
# 328       1
# 830       1
# Name: count, Length: 637, dtype: int64
#
# 637
#
# BsmtFinType2: object
#
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64
#
# 6
#
# BsmtFinSF2: int64
#
# BsmtFinSF2
# 0       1293
# 180        5
# 374        3
# 551        2
# 147        2
#         ...
# 532        1
# 165        1
# 1120       1
# 311        1
# 1029       1
# Name: count, Length: 144, dtype: int64
#
# 144
#
# BsmtUnfSF: int64
#
# BsmtUnfSF
# 0       118
# 728       9
# 384       8
# 600       7
# 300       7
#        ...
# 551       1
# 1257      1
# 605       1
# 467       1
# 136       1
# Name: count, Length: 780, dtype: int64
#
# 780
#
# TotalBsmtSF: int64
#
# TotalBsmtSF
# 0       37
# 864     35
# 672     17
# 912     15
# 1040    14
#         ..
# 1838     1
# 1581     1
# 707      1
# 611      1
# 1542     1
# Name: count, Length: 721, dtype: int64
#
# 721
#
# Heating: object
#
# Heating
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: count, dtype: int64
#
# 6
#
# HeatingQC: object
#
# HeatingQC
# Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: count, dtype: int64
#
# 5
#
# CentralAir: object
#
# CentralAir
# Y    1365
# N      95
# Name: count, dtype: int64
#
# 2
#
# Electrical: object
#
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64
#
# 5
#
# 1stFlrSF: int64
#
# 1stFlrSF
# 864     25
# 1040    16
# 912     14
# 894     12
# 848     12
#         ..
# 1509     1
# 2515     1
# 605      1
# 3138     1
# 1256     1
# Name: count, Length: 753, dtype: int64
#
# 753
#
# 2ndFlrSF: int64
#
# 2ndFlrSF
# 0       829
# 728      10
# 504       9
# 546       8
# 672       8
#        ...
# 1538      1
# 914       1
# 1067      1
# 1000      1
# 1152      1
# Name: count, Length: 417, dtype: int64
#
# 417
#
# LowQualFinSF: int64
#
# LowQualFinSF
# 0      1434
# 80        3
# 360       2
# 205       1
# 479       1
# 397       1
# 514       1
# 120       1
# 481       1
# 232       1
# 53        1
# 515       1
# 156       1
# 473       1
# 420       1
# 390       1
# 371       1
# 392       1
# 144       1
# 572       1
# 528       1
# 234       1
# 513       1
# 384       1
# Name: count, dtype: int64
#
# 24
#
# GrLivArea: int64
#
# GrLivArea
# 864     22
# 1040    14
# 894     11
# 1456    10
# 848     10
#         ..
# 2296     1
# 1123     1
# 1199     1
# 1473     1
# 1256     1
# Name: count, Length: 861, dtype: int64
#
# 861
#
# BsmtFullBath: int64
#
# BsmtFullBath
# 0    856
# 1    588
# 2     15
# 3      1
# Name: count, dtype: int64
#
# 4
#
# BsmtHalfBath: int64
#
# BsmtHalfBath
# 0    1378
# 1      80
# 2       2
# Name: count, dtype: int64
#
# 3
#
# FullBath: int64
#
# FullBath
# 2    768
# 1    650
# 3     33
# 0      9
# Name: count, dtype: int64
#
# 4
#
# HalfBath: int64
#
# HalfBath
# 0    913
# 1    535
# 2     12
# Name: count, dtype: int64
#
# 3
#
# BedroomAbvGr: int64
#
# BedroomAbvGr
# 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: count, dtype: int64
#
# 8
#
# KitchenAbvGr: int64
#
# KitchenAbvGr
# 1    1392
# 2      65
# 3       2
# 0       1
# Name: count, dtype: int64
#
# 4
#
# KitchenQual: object
#
# KitchenQual
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: count, dtype: int64
#
# 4
#
# TotRmsAbvGrd: int64
#
# TotRmsAbvGrd
# 6     402
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 2       1
# 14      1
# Name: count, dtype: int64
#
# 12
#
# Functional: object
#
# Functional
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: count, dtype: int64
#
# 7
#
# Fireplaces: int64
#
# Fireplaces
# 0    690
# 1    650
# 2    115
# 3      5
# Name: count, dtype: int64
#
# 4
#
# FireplaceQu: object
#
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64
#
# 5
#
# GarageType: object
#
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64
#
# 6
#
# GarageYrBlt: float64
#
# GarageYrBlt
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1927.0     1
# 1900.0     1
# 1906.0     1
# 1908.0     1
# 1933.0     1
# Name: count, Length: 97, dtype: int64
#
# 97
#
# GarageFinish: object
#
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# Name: count, dtype: int64
#
# 3
#
# GarageCars: int64
#
# GarageCars
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: count, dtype: int64
#
# 5
#
# GarageArea: int64
#
# GarageArea
# 0      81
# 440    49
# 576    47
# 240    38
# 484    34
#        ..
# 320     1
# 594     1
# 831     1
# 878     1
# 192     1
# Name: count, Length: 441, dtype: int64
#
# 441
#
# GarageQual: object
#
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64
#
# 5
#
# GarageCond: object
#
# GarageCond
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64
#
# 5
#
# PavedDrive: object
#
# PavedDrive
# Y    1340
# N      90
# P      30
# Name: count, dtype: int64
#
# 3
#
# WoodDeckSF: int64
#
# WoodDeckSF
# 0      761
# 192     38
# 100     36
# 144     33
# 120     31
#       ...
# 326      1
# 179      1
# 103      1
# 176      1
# 736      1
# Name: count, Length: 274, dtype: int64
#
# 274
#
# OpenPorchSF: int64
#
# OpenPorchSF
# 0      656
# 36      29
# 48      22
# 20      21
# 40      19
#       ...
# 11       1
# 523      1
# 125      1
# 137      1
# 236      1
# Name: count, Length: 202, dtype: int64
#
# 202
#
# EnclosedPorch: int64
#
# EnclosedPorch
# 0      1252
# 112      15
# 96        6
# 192       5
# 144       5
#        ...
# 54        1
# 136       1
# 148       1
# 140       1
# 99        1
# Name: count, Length: 120, dtype: int64
#
# 120
#
# 3SsnPorch: int64
#
# 3SsnPorch
# 0      1436
# 168       3
# 144       2
# 180       2
# 216       2
# 290       1
# 153       1
# 96        1
# 23        1
# 162       1
# 182       1
# 196       1
# 320       1
# 245       1
# 238       1
# 508       1
# 140       1
# 130       1
# 407       1
# 304       1
# Name: count, dtype: int64
#
# 20
#
# ScreenPorch: int64
#
# ScreenPorch
# 0      1344
# 192       6
# 120       5
# 224       5
# 189       4
#        ...
# 291       1
# 260       1
# 385       1
# 156       1
# 40        1
# Name: count, Length: 76, dtype: int64
#
# 76
#
# PoolArea: int64
#
# PoolArea
# 0      1453
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# Name: count, dtype: int64
#
# 8
#
# PoolQC: object
#
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64
#
# 3
#
# Fence: object
#
# Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: count, dtype: int64
#
# 4
#
# MiscFeature: object
#
# MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64
#
# 4
#
# MiscVal: int64
#
# MiscVal
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 1200        2
# 480         2
# 15500       1
# 800         1
# 350         1
# 3500        1
# 1300        1
# 54          1
# 620         1
# 560         1
# 1400        1
# 8300        1
# 1150        1
# 2500        1
# Name: count, dtype: int64
#
# 21
#
# MoSold: int64
#
# MoSold
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: count, dtype: int64
#
# 12
#
# YrSold: int64
#
# YrSold
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: count, dtype: int64
#
# 5
#
# SaleType: object
#
# SaleType
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: count, dtype: int64
#
# 9
#
# SaleCondition: object
#
# SaleCondition
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: count, dtype: int64
#
# 6
#
# SalePrice: int64
#
# SalePrice
# 140000    20
# 135000    17
# 155000    14
# 145000    14
# 190000    13
#           ..
# 202665     1
# 164900     1
# 208300     1
# 181500     1
# 147500     1
# Name: count, Length: 663, dtype: int64
#
# 663
#
# Численных признаков: 20, Категориальных признаков: 61, Неопределенных признаков: 0

# %%
cat_cols
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageCars',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  '3SsnPorch',
#  'PoolArea',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %%
preparer.print_feature_types()
# Out:
# Id: Тип признака: int64, Совпадает с истинным?: True
# MSSubClass: Тип признака: int64, Совпадает с истинным?: True
# MSZoning: Тип признака: object, Совпадает с истинным?: True
# LotFrontage: Тип признака: float64, Совпадает с истинным?: True
# LotArea: Тип признака: int64, Совпадает с истинным?: True
# Street: Тип признака: object, Совпадает с истинным?: True
# Alley: Тип признака: object, Совпадает с истинным?: True
# LotShape: Тип признака: object, Совпадает с истинным?: True
# LandContour: Тип признака: object, Совпадает с истинным?: True
# Utilities: Тип признака: object, Совпадает с истинным?: True
# LotConfig: Тип признака: object, Совпадает с истинным?: True
# LandSlope: Тип признака: object, Совпадает с истинным?: True
# Neighborhood: Тип признака: object, Совпадает с истинным?: True
# Condition1: Тип признака: object, Совпадает с истинным?: True
# Condition2: Тип признака: object, Совпадает с истинным?: True
# BldgType: Тип признака: object, Совпадает с истинным?: True
# HouseStyle: Тип признака: object, Совпадает с истинным?: True
# OverallQual: Тип признака: int64, Совпадает с истинным?: True
# OverallCond: Тип признака: int64, Совпадает с истинным?: True
# YearBuilt: Тип признака: int64, Совпадает с истинным?: True
# YearRemodAdd: Тип признака: int64, Совпадает с истинным?: True
# RoofStyle: Тип признака: object, Совпадает с истинным?: True
# RoofMatl: Тип признака: object, Совпадает с истинным?: True
# Exterior1st: Тип признака: object, Совпадает с истинным?: True
# Exterior2nd: Тип признака: object, Совпадает с истинным?: True
# MasVnrType: Тип признака: object, Совпадает с истинным?: True
# MasVnrArea: Тип признака: float64, Совпадает с истинным?: True
# ExterQual: Тип признака: object, Совпадает с истинным?: True
# ExterCond: Тип признака: object, Совпадает с истинным?: True
# Foundation: Тип признака: object, Совпадает с истинным?: True
# BsmtQual: Тип признака: object, Совпадает с истинным?: True
# BsmtCond: Тип признака: object, Совпадает с истинным?: True
# BsmtExposure: Тип признака: object, Совпадает с истинным?: True
# BsmtFinType1: Тип признака: object, Совпадает с истинным?: True
# BsmtFinSF1: Тип признака: int64, Совпадает с истинным?: True
# BsmtFinType2: Тип признака: object, Совпадает с истинным?: True
# BsmtFinSF2: Тип признака: int64, Совпадает с истинным?: True
# BsmtUnfSF: Тип признака: int64, Совпадает с истинным?: True
# TotalBsmtSF: Тип признака: int64, Совпадает с истинным?: True
# Heating: Тип признака: object, Совпадает с истинным?: True
# HeatingQC: Тип признака: object, Совпадает с истинным?: True
# CentralAir: Тип признака: object, Совпадает с истинным?: True
# Electrical: Тип признака: object, Совпадает с истинным?: True
# 1stFlrSF: Тип признака: int64, Совпадает с истинным?: True
# 2ndFlrSF: Тип признака: int64, Совпадает с истинным?: True
# LowQualFinSF: Тип признака: int64, Совпадает с истинным?: True
# GrLivArea: Тип признака: int64, Совпадает с истинным?: True
# BsmtFullBath: Тип признака: int64, Совпадает с истинным?: True
# BsmtHalfBath: Тип признака: int64, Совпадает с истинным?: True
# FullBath: Тип признака: int64, Совпадает с истинным?: True
# HalfBath: Тип признака: int64, Совпадает с истинным?: True
# BedroomAbvGr: Тип признака: int64, Совпадает с истинным?: True
# KitchenAbvGr: Тип признака: int64, Совпадает с истинным?: True
# KitchenQual: Тип признака: object, Совпадает с истинным?: True
# TotRmsAbvGrd: Тип признака: int64, Совпадает с истинным?: True
# Functional: Тип признака: object, Совпадает с истинным?: True
# Fireplaces: Тип признака: int64, Совпадает с истинным?: True
# FireplaceQu: Тип признака: object, Совпадает с истинным?: True
# GarageType: Тип признака: object, Совпадает с истинным?: True
# GarageYrBlt: Тип признака: float64, Совпадает с истинным?: True
# GarageFinish: Тип признака: object, Совпадает с истинным?: True
# GarageCars: Тип признака: int64, Совпадает с истинным?: True
# GarageArea: Тип признака: int64, Совпадает с истинным?: True
# GarageQual: Тип признака: object, Совпадает с истинным?: True
# GarageCond: Тип признака: object, Совпадает с истинным?: True
# PavedDrive: Тип признака: object, Совпадает с истинным?: True
# WoodDeckSF: Тип признака: int64, Совпадает с истинным?: True
# OpenPorchSF: Тип признака: int64, Совпадает с истинным?: True
# EnclosedPorch: Тип признака: int64, Совпадает с истинным?: True
# 3SsnPorch: Тип признака: int64, Совпадает с истинным?: True
# ScreenPorch: Тип признака: int64, Совпадает с истинным?: True
# PoolArea: Тип признака: int64, Совпадает с истинным?: True
# PoolQC: Тип признака: object, Совпадает с истинным?: True
# Fence: Тип признака: object, Совпадает с истинным?: True
# MiscFeature: Тип признака: object, Совпадает с истинным?: True
# MiscVal: Тип признака: int64, Совпадает с истинным?: True
# MoSold: Тип признака: int64, Совпадает с истинным?: True
# YrSold: Тип признака: int64, Совпадает с истинным?: True
# SaleType: Тип признака: object, Совпадает с истинным?: True
# SaleCondition: Тип признака: object, Совпадает с истинным?: True
# SalePrice: Тип признака: int64, Совпадает с истинным?: True
# Признаки, несоответствующие типу: []
# c:\Users\Maksim\Desktop\pet - проект\Datasets\Regression\prepare_data_framework.py:91: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   check = int(self.data[col].sample())
# []

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
data.drop(columns=nan_cols, inplace=True)

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour
# 0        1          60       RL     8450   Pave      Reg         Lvl  \
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch
# 0       AllPub    Inside       Gtl  ...             0         0           0  \
# 1       AllPub       FR2       Gtl  ...             0         0           0
# 2       AllPub    Inside       Gtl  ...             0         0           0
# 3       AllPub    Corner       Gtl  ...           272         0           0
# 4       AllPub       FR2       Gtl  ...             0         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 1455    AllPub    Inside       Gtl  ...             0         0           0
# 1456    AllPub    Inside       Gtl  ...             0         0           0
# 1457    AllPub    Inside       Gtl  ...             0         0           0
# 1458    AllPub    Inside       Gtl  ...           112         0           0
# 1459    AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0           0       0       2    2008        WD         Normal    208500
# 1           0       0       5    2007        WD         Normal    181500
# 2           0       0       9    2008        WD         Normal    223500
# 3           0       0       2    2006        WD        Abnorml    140000
# 4           0       0      12    2008        WD         Normal    250000
# ...       ...     ...     ...     ...       ...            ...       ...
# 1455        0       0       8    2007        WD         Normal    175000
# 1456        0       0       2    2010        WD         Normal    210000
# 1457        0    2500       5    2010        WD         Normal    266500
# 1458        0       0       4    2010        WD         Normal    142125
# 1459        0       0       6    2008        WD         Normal    147500
#
# [1460 rows x 62 columns]

# %%
remain_cols = list(set(cat_cols) - set(nan_cols))
remain_cols
# Out:
# ['OverallCond',
#  'Fireplaces',
#  'MSZoning',
#  'Condition1',
#  'MSSubClass',
#  'OverallQual',
#  'Exterior1st',
#  'ExterQual',
#  'BsmtFullBath',
#  'Neighborhood',
#  'HalfBath',
#  'Exterior2nd',
#  'RoofStyle',
#  'MoSold',
#  'ExterCond',
#  'Street',
#  'BldgType',
#  'LandSlope',
#  'HouseStyle',
#  'YrSold',
#  'CentralAir',
#  'TotRmsAbvGrd',
#  'Heating',
#  'BedroomAbvGr',
#  'SaleType',
#  'Condition2',
#  '3SsnPorch',
#  'PoolArea',
#  'KitchenAbvGr',
#  'LotConfig',
#  'KitchenQual',
#  'RoofMatl',
#  'PavedDrive',
#  'GarageCars',
#  'LandContour',
#  'SaleCondition',
#  'Functional',
#  'FullBath',
#  'LotShape',
#  'LowQualFinSF',
#  'BsmtHalfBath',
#  'HeatingQC',
#  'Foundation',
#  'MiscVal',
#  'Utilities']

# %%
le = LabelEncoder()
for col in remain_cols:
    data[col] = le.fit_transform(data[col])

data.head(5)
# Out:
#    Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour
# 0   1           5         3     8450       1         3            3  \
# 1   2           0         3     9600       1         3            3
# 2   3           5         3    11250       1         0            3
# 3   4           6         3     9550       1         0            3
# 4   5           5         3    14260       1         0            3
#
#    Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch
# 0          0          4          0  ...              0          0  \
# 1          0          2          0  ...              0          0
# 2          0          4          0  ...              0          0
# 3          0          0          0  ...            272          0
# 4          0          2          0  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0            0         0        0       1       2         8              4  \
# 1            0         0        0       4       1         8              4
# 2            0         0        0       8       2         8              4
# 3            0         0        0       1       0         8              0
# 4            0         0        0      11       2         8              4
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 62 columns]

# %%
num_cols
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
num_cols = list(set(num_cols) - set(nan_cols))
num_cols.remove('SalePrice')
num_cols
# Out:
# ['GrLivArea',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'BsmtFinSF1',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'BsmtUnfSF',
#  '1stFlrSF',
#  'YearRemodAdd',
#  'WoodDeckSF',
#  'YearBuilt',
#  '2ndFlrSF',
#  'GarageArea',
#  'Id',
#  'LotArea',
#  'BsmtFinSF2']

# %%
num_cols.remove("Id")

# %%
# num_cols = list(set(num_cols) - set(nan_cols))
scaler = StandardScaler()
data[num_cols] = scaler.fit_transform(data[num_cols])
data.head(5)
# Out:
#    MSSubClass  MSZoning   LotArea  Street  LotShape  LandContour  Utilities
# 0           5         3 -0.207142       1         3            3          0  \
# 1           0         3 -0.091886       1         3            3          0
# 2           5         3  0.073480       1         0            3          0
# 3           6         3 -0.096897       1         0            3          0
# 4           5         3  0.375148       1         0            3          0
#
#    LotConfig  LandSlope  Neighborhood  ...  EnclosedPorch  3SsnPorch
# 0          4          0             5  ...      -0.359325          0  \
# 1          2          0            24  ...      -0.359325          0
# 2          4          0             5  ...      -0.359325          0
# 3          0          0             6  ...       4.092524          0
# 4          2          0            15  ...      -0.359325          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0    -0.270208         0        0       1       2         8              4  \
# 1    -0.270208         0        0       4       1         8              4
# 2    -0.270208         0        0       8       2         8              4
# 3    -0.270208         0        0       1       0         8              0
# 4    -0.270208         0        0      11       2         8              4
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 61 columns]

# %%
data.drop(columns='Id', inplace= True)

# %%
data.to_csv("prepared_reg_data.csv")
